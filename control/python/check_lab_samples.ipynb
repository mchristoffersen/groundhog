# %% [markdown]
# # Check Lab Samples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lab_samples = np.fromfile("./lab_pulse_samples.dat", dtype=np.complex64, count=1000000)

# %%
data = np.real(lab_samples[16000:21000])

# %%
trig = 0.005
data_trig = data > trig
trig_loc = np.argmax(data_trig)
trace_len = 512
trace = np.zeros(trace_len, dtype=np.float32)
plt.plot(data_trig)

# %%
trace = trace + data[trig_loc-32 : trig_loc + trace_len - 32]

# %%
plt.plot(trace)

# %%
data_trig = data_trig[
                    trig_loc + trace_len :
                ]

# %%
plt.plot(data_trig)
print(trig_loc)
# Out:
# 3417
