# %% [markdown]
# # Check Lab Samples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.fromfile("./lab_pulse_samples.dat", dtype=np.complex64, count=1000000)

# %%
plt.plot(np.real(data)[16000:21000])
plt.show()

# %%
data = np.real(lab_samples[16000:21000])

# %%
trig = 0.005
data_trig = data > trig
trig_loc = np.argmax(data_trig)
trace_len = 512
trace = np.zeros(trace_len, dtype=np.float32)
plt.plot(data_trig)

# %%
trace = trace + data[trig_loc-32 : trig_loc + trace_len - 32]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-e8186ad9d449> in <module>
# ----> 1 trace = trace + data[trig_loc-32 : trig_loc + trace_len - 32]
#
# ValueError: operands could not be broadcast together with shapes (512,) (0,)

# %%
plt.plot(trace)
# Out:
# /home/langur/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
data_trig = data_trig[
                    trig_loc + trace_len :
                ]

# %%
plt.plot(data_trig)
print(trig_loc)
# Out:
# 3417
